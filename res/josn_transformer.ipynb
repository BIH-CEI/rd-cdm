# %%
import pandas as pd
import json

# %%
df = pd.read_excel('/Users/adam/Documents/git/rd-cdm/res/rd_cdm_v2_0_0/Copy of RD CDM v2.0.xlsx')

# %%
df
# Out:
#                      Section                                    Data Element  \
# 0                        NaN                                             NaN
# 1       1. Formal \nCriteria                                   1.1 Pseudonym
# 2                        NaN                           1.2 Date of Admission
# 3    2. Personal Information                               2.1 Date of birth
# 4                        NaN                                2.2 Sex at birth
# ..                       ...                                             ...
# 235                      NaN                           7.6 Biological sample
# 236                      NaN                                             NaN
# 237                      NaN                                             NaN
# 238                      NaN                           7.7 Link to a biobank
# 239            8. Disability  8.1 Classification of functioning / disability
#
# ...

# %%
json_output = df.to_json(orient='records')

# %%
with open('rd_cdm_v2.0.json', 'w') as json_file:
    json_file.write(json_output)
